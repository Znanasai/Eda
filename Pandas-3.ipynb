# %%
import pandas as pd
import matplotlib.pyplot as plt
rt=pd.read_csv('Visadataset.csv')

# %%
rt
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
sd=rt['case_status'].value_counts()
case_status=sd.keys()
Verification=sd.values
cols=['case_status','Verification']
dt=pd.DataFrame(zip(case_status,Verification),columns=cols)
dt.to_csv('case_status.csv')

# %%
sd=rt['case_status'].value_counts()
sd
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
rt.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
import seaborn as sns
order_continents='Asia','Europe','North america','South America','Africa','Oceania'
plt.figure(figsize=(8,5))
sns.countplot(data=rt,x='continent',order=order_continents)
plt.savefig('Continents_bar_chart_using _seaborn.jpg')
plt.show()

# %% [markdown]
# **How to create a folder**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
order_continents='Asia','Europe','North america','South America','Africa','Oceania'
plt.figure(figsize=(8,5))
sns.countplot(data=rt,x='continent',order=order_continents)
plt.savefig(f'{i} _seaborn.jpg')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dell\\online_cls\\EDA'

# %% [markdown]
# **os.mkdirs()**
# - makedirs create a leaf directory
# - means it will take the current working directory and create one extra folder
# - here my python file in **EDA**folder
# - Now i want to create a new folder **Graphs_seaborn**
# - which is one step ahead od EDA folder : EDA/graphs_seaborn
# - pass the full path inside the makedirs()

# %%
import os

i = 'C:\\Users\\dell\\online_cls\\EDA\\graph_seaborn'
os.mkdir(i)

# %%
try:
    root_dir=os.getcwd()
    root_dir
    new_folder='graph1'
    new_dir=os.path.join(root_dir,new_folder)
    new_dir
    os.makedirs(new_dir)
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\dell\\online_cls\\EDA\\graph1'

# %%
k=os.listdir('C:\\Users\\dell\\online_cls\\EDA\\bank_files')
k
# Out:
# ['contact.csv',
#  'default.csv',
#  'education.csv',
#  'housing.csv',
#  'job.csv',
#  'loan.csv',
#  'marital.csv',
#  'month.csv',
#  'poutcome.csv',
#  'y.csv']

# %%
visa_df=pd.read_csv('bank.csv',delimiter=';')

# %%
cat_list=[i for i,j in dict(visa_df.dtypes).items() if j=='object']
num_list=[i for i,j in dict(visa_df.dtypes).items() if j!='object']

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os 
root_dir=os.getcwd()
new_folder='bank_files'
cr=os.path.join(root_dir,new_folder)
for i in k:
    pf=pd.read_csv(f'{cr}\\{i}')
    plt.bar(i[:-4],'Count',data=pf)
    plt.title('bar chart')
    plt.xlabel(i[:-4])
    plt.ylabel('Count')
    plt.show()
print(pf)
# Out:
#      y  Count
# 0   no   4000
# 1  yes    521

# %% [markdown]
# **Subplot**

# %% [markdown]
# - If we have multiple plots when we apply for loop it is giving one by one
# - It is hard to see all the graphs
# - Subplots is a kind of a matrix
# - Suppose we have 2x2 matrix means 4 values , means 4 plors we can plot
# - First plot position represents with : (2,2,1)
# - Second plot position represents with : (2,2,2)
# - Third plot position represents with : (2,2,3)

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
import seaborn as sns
cols=cat_list[1:]
plt.figure(figsize=(16,14))
for i in range(len(cat_list)):
    sns.countplot(x=cat_list[i],data=visa_df,width=0.4)
    plt.subplot(4,4,i+1)
    plt.tight_layout()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming cat_list and visa_df are already defined
cols = cat_list[1:]
plt.figure(figsize=(16,14))
for i in range(len(cat_list)):
    plt.subplot(3,3,i+1)
    sns.countplot(x=cat_list[i], data=visa_df, width=0.4)
    plt.tight_layout()  # Adjust layout to prevent overlap

#plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 8
#       6 plt.figure(figsize=(16,14))
#       7 for i in range(len(cat_list)):
# ----> 8     plt.subplot(3, 3, i+1)
#       9     sns.countplot(x=cat_list[i], data=visa_df, width=0.4)
#      10     plt.tight_layout()
#
# File E:\E\Lib\site-packages\matplotlib\pyplot.py:1425, in subplot(*args, **kwargs)
#    1422 fig = gcf()
#    1424 # First, search for an existing subplot with a matching spec.
# -> 1425 key = SubplotSpec._from_subplot_args(fig, args)
#    1427 for ax in fig.axes:
#    1428     # If we found an Axes at the position, we can re-use it if the user passed no
#    1429     # kwargs or if the axes class and kwargs are identical.
#    1430     if (ax.get_subplotspec() == key
#    1431         and (kwargs == {}
#    1432              or (ax._projection_init
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cols_to_plot = cat_list[:9]  
plt.figure(figsize=(16, 14))
for i in range(len(cols_to_plot)):
    plt.subplot(3, 3, i+1)
    sns.countplot(x=cols_to_plot[i], data=visa_df, width=0.4)
    plt.tight_layout()
#plt.show()

# %%
len(cols_to_plot)
# Out:
# 9

# %%
len(cat_list[1:])
# Out:
# 9

# %%
visa_df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
cdr=rt['continent'].value_counts()
ao=cdr.plot(kind='bar')
ao.bar_label(ao.containers[0])
plt.show()

# %%
cdr=rt['continent'].value_counts()
ao=cdr.plot(kind='bar')
ao.bar_label(ao.containers[0])
plt.show()

# %%
for i in ao.containers[0]:
    print(i)
# Out:
# Rectangle(xy=(-0.25, 0), width=0.5, height=16861, angle=0)
# Rectangle(xy=(0.75, 0), width=0.5, height=3732, angle=0)
# Rectangle(xy=(1.75, 0), width=0.5, height=3292, angle=0)
# Rectangle(xy=(2.75, 0), width=0.5, height=852, angle=0)
# Rectangle(xy=(3.75, 0), width=0.5, height=551, angle=0)
# Rectangle(xy=(4.75, 0), width=0.5, height=192, angle=0)

# %%
###
import seaborn as sns
order_continents='Asia','Europe','North america','South America','Africa','Oceania'
plt.figure(figsize=(8,5))
sns.countplot(data=rt,x='continent',order=order_continents)
plt.savefig('Continents_bar_chart_using _seaborn.jpg')
plt.show()
###
import matplotlib.pyplot as plt
sd=rt['continent'].value_counts()
continents=sd.keys()
Number_of_applicants=sd.values
cols=['continents','Number_of_applicants']
dt=pd.DataFrame(zip(continents,Number_of_applicants),columns=cols)
plt.bar('continents','Number_of_applicants',data=dt)
plt.title("Bar plot")
plt.xlabel('Continents')
plt.ylabel('Number of applicants')
plt.savefig('Data.jpg')
plt.show()#should be at last
###
cdr=rt['continent'].value_counts()
ao=cdr.plot(kind='bar')
ao.bar_label(ao.containers[0])
plt.show()

# %% [markdown]
# ## Pie Chart

# %% [markdown]
# - Under matplotlib package
# - It will take keys and values
# - we will get from value counts

# %%
round(rt['continent'].value_counts(normalize=True)*100,2)
# Out:
# continent
# Asia             66.17
# Europe           14.65
# North America    12.92
# South America     3.34
# Africa            2.16
# Oceania           0.75
# Name: proportion, dtype: float64

# %%
keys=rt['continent'].value_counts().keys()
value=rt['continent'].value_counts().values
plt.pie(value,labels=keys,autopct='%0.2f%%')
plt.show()

# %%
keys=rt['continent'].value_counts().keys()
value=rt['continent'].value_counts().values
plt.pie(value,explode=[0.15,0.15,0.15,0.15,0.15,0.15],labels=keys,autopct='%0.2f%%',startangle=180)
plt.show()

# %% [markdown]
# ## Numerical Analysis

# %%
max(rt['prevailing_wage'])
# Out:
# 319210.27

# %%
count=len(rt['prevailing_wage'])
max_wage=max(rt['prevailing_wage'])
min_wage=min(rt['prevailing_wage'])
print(f"the no of wage samples :{count}")
print(f"max wage sample :{max_wage}")
print(f"min wage sample :{min_wage}")
# Out:
# the no of wage samples :25480
# max wage sample :319210.27
# min wage sample :2.1367

# %%
rt['prevailing_wage'].mean()
# Out:
# 74455.81459209183

# %%
rt['prevailing_wage'].median()
# Out:
# 70308.20999999999

# %%
mean_wage=round(rt['prevailing_wage'].mean(),2)
median_wage=round(rt['prevailing_wage'].median(),2)
print("the avg wage is :",mean_wage)
print("the meadian wage is :",median_wage)
# Out:
# the avg wage is : 74455.81
# the meadian wage is : 70308.21

# %%
standard_wage=round(rt['prevailing_wage'].std(),2)

# %%
values=[count,min_wage,max_wage,mean_wage,median_wage,standard_wage]
index=['count','min','max','mean','median','std']
cols=['prevailing_wage']
pd.DataFrame(values,index=index,columns=cols)
# Out:
#         prevailing_wage
# count        25480.0000
# min              2.1367
# max         319210.2700
# mean         74455.8100
# median       70308.2100
# std          52815.9400

# %%
rt.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
import numpy as np
#takes two args
#a: array means data; q:value which percentile we want
np.percentile(rt['prevailing_wage'],25)
# Out:
# 34015.479999999996

# %% [markdown]
# **Quantile**
# - If numpy we have quantile method
# - a: array means data
# - q:value which percentile we want
# - if we want 25p then value of q=0.25

# %%
p_25=np.quantile(rt['prevailing_wage'],.25)

# %%
p_25=np.percentile(rt['prevailing_wage'],25)
p_75=np.percentile(rt['prevailing_wage'],75)
p_50=np.percentile(rt['prevailing_wage'],50)

# %%
wage_data=rt['prevailing_wage']
wage_data
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
wage_data=rt['prevailing_wage']
con=wage_data<p_25
con1=wage_data<p_50
con2=wage_data<p_75
print(len(rt[con]),len(rt[con1]),len(rt[con2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 wage_data=rt['prevailing_wage']
# ----> 2 con=wage_data<p_25
#       3 con1=wage_data<p_50
#       4 con2=wage_data<p_75
#
# NameError: name 'p_25' is not defined

# %% [markdown]
# ## Empirical Rule

# %%
One Standard Deviation (µ ± σ): 68% of Data

Two Standard Deviation (µ ± 2σ): 95% of Data

Three Standard Deviation (µ ± 3σ): 99.7% of Data

# %%
mu=rt['prevailing_wage'].mean()
sigma=rt['prevailing_wage'].std()*2
lb=mu-sigma
ub=mu+sigma
con1=(rt['prevailing_wage']<ub)&(rt['prevailing_wage']>lb)
rt[con1]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(con1)
# Out:
# 25480

# %%
rt.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **Histogram**

# %% [markdown]
# - By applying empirical rule we observed slight deviation in the count of data
# - Also mean is slightly deviated from Median
# - This gives an indication the data does not follow normal distribution
# - to understand more clearly will visualize the data
# - it is numerical data,the plot name is **Histogram**
# - Histogram is a graph between class intervals and class interval frequency
# - The plot is available in **matplotlib**
# - the method name is **hist**

# %%
import matplotlib.pyplot as plt 
plt.hist(rt['prevailing_wage'],bins=12)
# Out:
# (array([5230., 4411., 4790., 4483., 3422., 1772.,  552.,  339.,  235.,
#          156.,   73.,   17.]),
#  array([2.13670000e+00, 2.66028145e+04, 5.32034923e+04, 7.98041700e+04,
#         1.06404848e+05, 1.33005526e+05, 1.59606203e+05, 1.86206881e+05,
#         2.12807559e+05, 2.39408237e+05, 2.66008914e+05, 2.92609592e+05,
#         3.19210270e+05]),
#  <BarContainer object of 12 artists>)

# %%
wage_data=rt['prevailing_wage']
count,bin,x=plt.hist(wage_data,bins=12)
print(len(count))
print(len(bin))
# Out:
# 12
# 13

# %% [markdown]
# **Verify below two statements**
# - 3863 observations are available between 2.136 to 15962.543

# %%
lb=2.13670000e+00
ub=2.66028145e+04
con1=rt['prevailing_wage']<=ub
con2=rt['prevailing_wage']>=lb
con3=con1&con2
print(len(rt[con3]))
# Out:
# 5230

# %%
count
# Out:
# array([5230., 4411., 4790., 4483., 3422., 1772.,  552.,  339.,  235.,
#         156.,   73.,   17.])

# %%
bin
# Out:
# array([2.13670000e+00, 2.66028145e+04, 5.32034923e+04, 7.98041700e+04,
#        1.06404848e+05, 1.33005526e+05, 1.59606203e+05, 1.86206881e+05,
#        2.12807559e+05, 2.39408237e+05, 2.66008914e+05, 2.92609592e+05,
#        3.19210270e+05])

# %%
x
# Out:
# <BarContainer object of 12 artists>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

visa_df=pd.read_csv('Visadataset.csv')
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data,vert=False)
plt.title('Boxplot')
plt.xlabel('Wages')
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
sns.boxplot(wage_data,orient='v')
plt.title('Boxplot')
plt.xlabel('Wages')
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
plt.figure(figsize=(14,3))
plt.suptitle('Comparison of Histogram with Boxplot')
plt.subplot(1,2,1)
plt.hist(wage_data,bins=20)
plt.xlabel('Histogram')
plt.subplot(1,2,2)
plt.boxplot(wage_data,vert=False)
plt.xlabel('boxplot')
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
plt.figure(figsize=(14,3))
plt.suptitle('Comparison of Histogram with Boxplot')
plt.subplot(1,2,1).hist(wage_data,bins=20)

plt.xlabel('Histogram')
plt.subplot(1,2,2).boxplot(wage_data,vert=False)

plt.xlabel('boxplot')
plt.show()

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
con1=wage_data<lb
con2=wage_data>ub
con3=con1|con2
outliers_data=wage_data[con3]
outliers_data
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
outliers_df=visa_df[con3]
outliers_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
con1=wage_data>lb
con2=wage_data<ub
con3=con1&con2
non_outliers_data=wage_data[con3]
non_outliers_data
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25474     51104.7800
# 25475     77092.5700
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25053, dtype: float64

# %%
non_outliers_df=visa_df[con3]
non_outliers_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
q1 = np.percentile(wage_data, 25)
q2 = np.percentile(wage_data, 50)  # Median
q3 = np.percentile(wage_data, 75)
IQR = q3 - q1
lb = q1 - 1.5 * IQR
ub = q3 + 1.5 * IQR
con1 = wage_data < lb
con2 = wage_data > ub
con3 = con1 | con2
wage_data[con3] = q2
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.boxplot(wage_data,vert=False)
plt.title("Boxplot of Wage Data after Outlier Replacement")
plt.subplot(1, 2, 2)
plt.hist(wage_data, bins=30, edgecolor='black')
plt.title("Histogram of Wage Data after Outlier Replacement")
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_5036\2069985630.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wage_data[con3] = q2

# %%
import pandas as pd
import matplotlib.pyplot as plt
rt=pd.read_csv('Visadataset.csv')

# %%
rt['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
rt['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
con1=rt['continent']=='Asia'
con2=rt['case_status']=='Certified'
con3=con1&con2
rt[con3]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 10        EZYV11      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
continents=rt['continent'].unique()
certified_list,denied_list=[],[]
for i in continents:
    con1=rt['continent']==i
    con2=rt['case_status']=='Certified'
    con4=rt['case_status']=='Denied'
    con3=con1&con2
    den_c=con1&con4
    print(f'the count of case status accepted is {len(rt[con3])}')
    print(f'the count of case status denied is {len(rt[den_c])}')
    certified_list.append(len(rt[con3]))
    denied_list.append(len(rt[den_c]))
# Out:
# the count of case status accepted is 11012
# the count of case status denied is 5849
# the count of case status accepted is 397
# the count of case status denied is 154
# the count of case status accepted is 2037
# the count of case status denied is 1255
# the count of case status accepted is 2957
# the count of case status denied is 775
# the count of case status accepted is 493
# the count of case status denied is 359
# the count of case status accepted is 122
# the count of case status denied is 70

# %%
continents
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
certified_list
# Out:
# [11012, 397, 2037, 2957, 493, 122]

# %%
cols=['Continents','Certified']
df3=pd.DataFrame(zip(continents,certified_list),columns=cols)
df3
# Out:
#       Continents  Certified
# 0           Asia      11012
# 1         Africa        397
# 2  North America       2037
# 3         Europe       2957
# 4  South America        493
# 5        Oceania        122

# %%
cols=['Certified','Denied']
df4=pd.DataFrame(zip(certified_list,denied_list),index=continents,columns=cols)
df4
# Out:
#                Certified  Denied
# Asia               11012    5849
# Africa               397     154
# North America       2037    1255
# Europe              2957     775
# South America        493     359
# Oceania              122      70

# %% [markdown]
# $$CROSS-TAB$$

# %% [markdown]
# - the above data frame we can make by using a method:**Cross tab**
# - it is available in pandas

# %%
pd.crosstab(rt['continents'],rt['case_status'])
